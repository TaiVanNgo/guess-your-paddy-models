# %% [markdown]
# # <h1 align="center">COSC2753 - Machine Learning</h1>
#
# <h2 align="center">Task 3: Age Prediction</h2>

# %% [markdown]
# # TABLE OF CONTENT
#
# [I. IMPORT NECESSARY LIBRARIES](#i-import-necessary-libraries)
#
# [II. MODEL TRAINING: Age Regression](#ii-model-training-age-regression)
#
#   - [1) Dataset Preprocessing](#1-data-preprocessing)
#
#   - [2) Setup Global Variable](#2-setup-global-variables)
#
#   - [3) Store Image in Generator](#3-store-image-in-generator)
#
#   - [4) Baseline Models](#4-baseline-models)
#
#   - [5) Model Selection and Tuning](#5-model-selection-and-tuning)
#
# [#III. MODEL PERFORMANCE VISUALIZATION](#iii-model-performance-visualization)

# %% [markdown]
# # I. IMPORT NECESSARY LIBRARIES

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np
import random
import importlib

# Data preprocessing
from sklearn.model_selection import train_test_split

# Import custom libraries
import utils.visualizations as vi
import utils.preprocessing as pr
import utils.model_training as mt

importlib.reload(vi)
importlib.reload(pr)
importlib.reload(mt);

# %% [markdown]
# ## Import Tensorflow for TensorFlow ≤ 2.12

# %%
# # Deep learning libraries
# import tensorflow as tf
# from tensorflow.keras import layers, models
# from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Flatten, Dropout
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.initializers import GlorotUniform
# from tensorflow.keras.layers import Conv2D, MaxPooling2D
# from tensorflow.keras.applications import NASNetMobile
# from tensorflow.keras.models import load_model, Model

# %% [markdown]
# ## Using Keras for Keras 3.x with TensorFlow ≥ 2.13

# %%
# Deep learning libraries
import tensorflow as tf
from keras import Sequential, layers, models, Input
from keras.regularizers import l2
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.src.legacy.preprocessing.image import ImageDataGenerator
from keras.initializers import GlorotUniform
from keras.applications import MobileNetV3Small, ResNet50V2, NASNetMobile
from keras.models import Model, load_model

# %% [markdown]
# # II.MODEL TRAINING: AGE REGRESSION

# %% [markdown]
# To ensure that the results are stable for multiple run time, we setup the seed for dataset

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## 1) Dataset Preprocessing

# %%
df = pd.read_csv('./inputs/training_df.csv')
df
# Out:
#          image_id                  label variety  age  \
# 0      100330.jpg  bacterial_leaf_blight   ADT45   45
# 1      100365.jpg  bacterial_leaf_blight   ADT45   45
# 2      100382.jpg  bacterial_leaf_blight   ADT45   45
# 3      100632.jpg  bacterial_leaf_blight   ADT45   45
# 4      101918.jpg  bacterial_leaf_blight   ADT45   45
# ...           ...                    ...     ...  ...
# 10402  107607.jpg                 tungro   Zonal   55
# 10403  107811.jpg                 tungro   Zonal   55
# 10404  108547.jpg                 tungro   Zonal   55
# 10405  110245.jpg                 tungro   Zonal   55
# 10406  110381.jpg                 tungro   Zonal   55
#
#                                               image_path
# 0      ./inputs/train_images/bacterial_leaf_blight/10...
# 1      ./inputs/train_images/bacterial_leaf_blight/10...
# 2      ./inputs/train_images/bacterial_leaf_blight/10...
# 3      ./inputs/train_images/bacterial_leaf_blight/10...
# 4      ./inputs/train_images/bacterial_leaf_blight/10...
# ...                                                  ...
# 10402            ./inputs/train_images/tungro/107607.jpg
# 10403            ./inputs/train_images/tungro/107811.jpg
# 10404            ./inputs/train_images/tungro/108547.jpg
# 10405            ./inputs/train_images/tungro/110245.jpg
# 10406            ./inputs/train_images/tungro/110381.jpg
#
# [10407 rows x 5 columns]

# %% [markdown]
# ## 2) Task 3: Predict Age's Plant

# %% [markdown]
# **Justification for using Regression in Task 3:**
# - Continuous Output: Age is a continuous variable, not discreates classes so regression can pre-dict exact values without losing precision
# - Avoid Information Loss: Regression can predict directly the exact value of age while Classifi-cation requires binning ages into categories which can result in reducing accuracy and infor-mation.
# - Suitable Loss Functions: Regression uses losses such as MAE and MSE that directly measure prediction errors on continuous targets.

# %% [markdown]
# ### 2.1) Data Preparation

# %%
# Define random_state
random_state = 42

train_df, val_df = train_test_split(df, test_size=0.2, random_state=random_state)

vi.print_header("Train Dataset shape")
print("Number of Rows: ", train_df.shape[0])
print("Number of Columns: ", train_df.shape[1])

vi.print_header("Validation Dataset Shape")
print("Number of Rows: ", val_df.shape[0])
print("Number of Columns: ", val_df.shape[1])
# Out:
# +-----------------------------------------+
# |           TRAIN DATASET SHAPE           |
# +-----------------------------------------+
# Number of Rows:  8325
# Number of Columns:  5
# +----------------------------------------------+
# |           VALIDATION DATASET SHAPE           |
# +----------------------------------------------+
# Number of Rows:  2082
# Number of Columns:  5

# %% [markdown]
# We can observe that the age distribution is quite imbalanced, with`70` classes account for 29.7% of the dataset, while minority classes such as `62` and `82` accounts for less than 0.5% of the dataset. However, in this task we will consider it as regression problem based on the justification above so the imbalance is not a problem.

# %%
vi.visualize_category_distribution(train_df, "age")

# %%
train_df["age"].value_counts()
# Out:
# age
# 70    2469
# 60    1346
# 50     835
# 75     690
# 65     622
# 55     449
# 72     442
# 45     410
# 67     318
# 68     201
# 80     174
# 57     168
# 47      94
# 73      34
# 77      32
# 66      32
# 62       5
# 82       4
# Name: count, dtype: int64

# %% [markdown]
# **Global Variables**

# %% [markdown]
# We set batch size to 32 and the Input_DIM as 64,64,3 for faster testing, in the final code we agreed to set the code to 128,128,3 for the image clarity

# %%
BATCH_SIZE = 32
INPUT_DIM = (64,64,3)

# %% [markdown]
# **Image Generator**
#
# Using class_mode = 'raw' to return the age as a continuous value

# %%
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

train_generator_age = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="",
    x_col='image_path',
    y_col='age',
    target_size= (64,64),
    batch_size= BATCH_SIZE,
    class_mode='raw',
    shuffle=True,
    seed=42
)

val_generator_age = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory="",
    x_col='image_path',
    y_col='age',
    target_size=(64, 64),
    batch_size=BATCH_SIZE,
    class_mode='raw',
    shuffle=False,
    seed=42
)
# Out:
# Found 8325 validated image filenames.
# Found 2082 validated image filenames.

# %% [markdown]
# ### 2.2) Baseline Model

# %% [markdown]
# **Summary Table**
#
# | Model        | Parameters | Strengths                        | Typical Applications              |
# |--------------|------------|---------------------------------|---------------------------------|
# | MobileNetV3  | ~1.5M–5.4M | Lightweight, fast, efficient     | Mobile/edge devices, real-time  |
# | ResNet50V2   | ~25M       | Deep, accurate, stable training  | General vision tasks, transfer learning |
# | NASNetMobile | ~5.3M      | NAS-designed, efficient modular  | Mobile vision tasks, custom solutions |

# %% [markdown]
# **MobileNetV3Small**
#
# 1. **Optimized for Resource-Constrained Environments**
#    Its small model size and low computational cost enable fast inference, ideal for real-time applications in agricultural image analysis where hardware resources may be limited.
#
# 2. **Good Balance of Speed and Accuracy**
#    MobileNetV3’s architecture, especially the “Small” variant, strikes a balance that supports rapid training and deployment without significant loss in performance on fine-grained tasks like paddy variety classification.
#
# 3. **Flexible Transfer Learning**
#    MobileNetV3 supports transfer learning with pretrained weights, accelerating convergence and helping mitigate issues related to imbalanced datasets by leveraging rich feature representations.

# %%
MobileNetV3Small_base = MobileNetV3Small(
        input_shape= INPUT_DIM,
        include_top=False,
        weights=None,  
        pooling='avg'  
)

x = MobileNetV3Small_base.output
output  = Dense(1, activation='linear')(x)
MobileNetV3Small_model = Model(inputs=MobileNetV3Small_base.input, outputs=output)

MobileNetV3Small_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 64, 64, 3) │          0 │ input_layer[0][0] │
# │ (Rescaling)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 32, 32,    │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 32, 32,    │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 33, 33,    │          0 │ activation[0][0]  │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 16, 16,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 16, 16,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 16, 16,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │          0 │ re_lu[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │        136 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 8)   │          0 │ expanded_conv_sq… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 1, 1, 16)  │        144 │ expanded_conv_sq… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 16)  │          0 │ expanded_conv_sq… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 1, 1, 16)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 16)  │          0 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_sque… │ (None, 16, 16,    │          0 │ re_lu[0][0],      │
# │ (Multiply)          │ 16)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 16, 16,    │        256 │ expanded_conv_sq… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 16, 16,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 16, 16,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 16, 16,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 17, 17,    │          0 │ re_lu_2[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 8, 8, 72)  │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 8, 8, 72)  │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 8, 8, 72)  │          0 │ expanded_conv_1_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 8, 8, 24)  │      1,728 │ re_lu_3[0][0]     │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 8, 8, 24)  │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 8, 8, 88)  │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 8, 8, 88)  │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 8, 8, 88)  │          0 │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 8, 8, 88)  │        792 │ re_lu_4[0][0]     │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 8, 8, 88)  │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 8, 8, 88)  │          0 │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 8, 8, 24)  │      2,112 │ re_lu_5[0][0]     │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 8, 8, 24)  │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 8, 8, 24)  │          0 │ expanded_conv_1_… │
# │ (Add)               │                   │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 8, 8, 96)  │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 8, 8, 96)  │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 8, 8, 96)  │          0 │ expanded_conv_3_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 11, 11,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 4, 4, 96)  │      2,400 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 4, 4, 96)  │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 4, 4, 96)  │          0 │ expanded_conv_3_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │          0 │ activation_2[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      2,328 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 96)  │      2,400 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 96)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 1, 1, 96)  │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 96)  │          0 │ re_lu_6[0][0]     │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 4, 4, 96)  │          0 │ activation_2[0][… │
# │ (Multiply)          │                   │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 4, 4, 40)  │      3,840 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 4, 4, 40)  │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 4, 4, 240) │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 4, 4, 240) │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None,
│ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 2, 2, 96)  │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 2, 2, 576) │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 2, 2, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 2, 2, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 2, 2, 576) │     14,400 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 2, 2, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 2, 2, 576) │          0 │ expanded_conv_10… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │     83,088 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 144) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 576) │     83,520 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 1, 1, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 576) │          0 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 1, 1, 576) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 2, 2, 576) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 2, 2, 96)  │     55,296 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 2, 2, 96)  │        384 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_a… │ (None, 2, 2, 96)  │          0 │ expanded_conv_9_… │
# │ (Add)               │                   │            │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 2, 2, 576) │     55,296 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 2, 2, 576) │      2,304 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 2, 2, 576) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 576)       │          0 │ activation_17[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │        577 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 939,697 (3.58 MB)
#  Trainable params: 927,585 (3.54 MB)
#  Non-trainable params: 12,112 (47.31 KB)

# %%
MobileNetV3Small_model.compile(optimizer='adam',loss="mse", metrics=["mae"])

# Train the EfficientNetB0 model
MobileNetV3Small_history = MobileNetV3Small_model.fit(
    train_generator_age, validation_data=val_generator_age,
    epochs=20, verbose=1,
)
# Out:
# c:\Anaconda\envs\tf219_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 183s 638ms/step - loss: 3116.4983 - mae: 54.1407 - val_loss: 2076.2803 - val_mae: 44.6682
# Epoch 2/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 54s 208ms/step - loss: 107.7076 - mae: 8.8874 - val_loss: 1596.8016 - val_mae: 38.9329
# Epoch 3/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 57s 220ms/step - loss: 65.9277 - mae: 6.7013 - val_loss: 1560.2739 - val_mae: 38.4609
# Epoch 4/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 58s 221ms/step - loss: 59.5367 - mae: 6.1976 - val_loss: 1511.7345 - val_mae: 37.8246
# Epoch 5/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 59s 226ms/step - loss: 52.8814 - mae: 5.7336 - val_loss: 1468.7299 - val_mae: 37.2518
# Epoch 6/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 55s 211ms/step - loss: 44.4746 - mae: 5.1467 - val_loss: 1411.4878 - val_mae: 36.4754
# Epoch 7/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 55s 211ms/step - loss: 39.1060 - mae: 4.7554 - val_loss: 1366.6818 - val_mae: 35.8560
# Epoch 8/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 69s 263ms/step - loss: 31.2516 - mae: 4.1446 - val_loss: 1331.4474 - val_mae: 35.3612
# Epoch 9/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 64s 244ms/step - loss: 26.3075 - mae: 3.8030 - val_loss: 1233.4845 - val_mae: 33.9478
# Epoch 10/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 54s 208ms/step - loss: 22.6874 - mae: 3.5374 - val_loss: 1151.7148 - val_mae: 32.7213
# Epoch 11/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 57s 217ms/step - loss: 19.6302 - mae: 3.2611 - val_loss: 1122.2281 - val_mae: 32.2676
# Epoch 12/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 76s 290ms/step - loss: 15.1686 - mae: 2.8920 - val_loss: 1004.5308 - val_mae: 30.3891
# Epoch 13/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 56s 214ms/step - loss: 13.7975 - mae: 2.7174 - val_loss: 975.5178 - val_mae: 29.9079
# Epoch 14/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 68s 259ms/step - loss: 12.8955 - mae: 2.6637 - val_loss: 741.5395 - val_mae: 25.7035
# Epoch 15/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 61s 232ms/step - loss: 13.5988 - mae: 2.6992 - val_loss: 303.7578 - val_mae: 15.3407
# Epoch 16/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 62s 236ms/step - loss: 12.8784 - mae: 2.5518 - val_loss: 268.9120 - val_mae: 14.3391
# Epoch 17/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 63s 240ms/step - loss: 11.0023 - mae: 2.4180 - val_loss: 90.2225 - val_mae: 7.3374
# Epoch 18/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 64s 244ms/step - loss: 12.5352 - mae: 2.4842 - val_loss: 177.9783 - val_mae: 10.3363
# Epoch 19/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 66s 255ms/step - loss: 12.3976 - mae: 2.4801 - val_loss: 1275.9717 - val_mae: 34.5698
# Epoch 20/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 64s 246ms/step - loss: 8.9657 - mae: 2.1949 - val_loss: 2135.0112 - val_mae: 45.3039

# %%
mt.save_model_and_history(
    MobileNetV3Small_model,
    MobileNetV3Small_history,
    model_name="mobilenetv3small_model",
    model_dir="models",
    history_dir="models/history",
)
# Out:
# Model saved to models\mobilenetv3small_model.keras
# Full history saved to models/history\mobilenetv3small_model_history.pkl

# %%
mt.plot_learning_curve(
    MobileNetV3Small_history.history["loss"],
    MobileNetV3Small_history.history["val_loss"],
    MobileNetV3Small_history.history["mae"],
    MobileNetV3Small_history.history["val_mae"],
    metric_name="MAE",
)

# %% [markdown]
# **ResNet50V2**
#
# 1. **Improved Residual Learning**
#    ResNet50V2 introduces pre-activation residual blocks that improve gradient flow, making it easier to train deeper networks capable of capturing intricate visual patterns in paddy images.
#
# 2. **Enhanced Feature Extraction**
#    Its deep architecture efficiently learns hierarchical features, enabling precise discrimination of subtle differences between paddy disease types and varieties.
#
# 3. **Strong Regularization and Generalization**
#    Pre-activation and batch normalization layers help reduce overfitting, which is crucial when handling imbalanced classes or limited data samples in agricultural datasets.
#
# 4. **Robustness with Data Augmentation**
#    ResNet50V2’s design works well with augmented data, enhancing model robustness and helping maintain accuracy across varying field conditions.

# %%
ResNet50V2_base = ResNet50V2(
    input_shape=INPUT_DIM,
    include_top=False,
    weights=None,  
    pooling='avg'  
)

x = ResNet50V2_base.output
output = Dense(1, activation='linear')(x)

ResNet50V2_model = Model(inputs=ResNet50V2_base.input, outputs=output)

ResNet50V2_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 70, 70, 3) │          0 │ input_layer_1[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 32, 32,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 34, 34,    │          0 │ conv1_conv[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 16, 16,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 16, 16,    │        256 │ pool1_pool[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 16, 16,    │          0 │ conv2_block1_pre… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 16, 16,    │      4,096 │ conv2_block1_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 16, 16,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 16, 16,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_pad  │ (None, 18, 18,    │          0 │ conv2_block1_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 16, 16,    │     36,864 │ conv2_block1_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 16, 16,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 16, 16,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 16, 16,    │     16,640 │ conv2_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 16, 16,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 16, 16,    │          0 │ conv2_block1_0_c… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 16, 16,    │      1,024 │ conv2_block1_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 16, 16,    │          0 │ conv2_block2_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 16, 16,    │     16,384 │ conv2_block2_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 16, 16,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 16, 16,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_pad  │ (None, 18, 18,    │          0 │ conv2_block2_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 16, 16,    │     36,864 │ conv2_block2_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 16, 16,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 16, 16,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 16, 16,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 16, 16,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 16, 16,    │      1,024 │ conv2_block2_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3
│
# │ (Add)               │ 1024)             │            │ conv4_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 4, 4,      │      4,096 │ conv4_block1_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 4, 4,      │          0 │ conv4_block2_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 4, 4,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 4, 4,      │      4,096 │ conv4_block2_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 4, 4,      │          0 │ conv4_block3_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 4, 4,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 4, 4,      │      4,096 │ conv4_block3_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 4, 4,      │          0 │ conv4_block4_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block4_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block4_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block4_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 4, 4,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 4, 4,      │      4,096 │ conv4_block4_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 4, 4,      │          0 │ conv4_block5_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block5_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block5_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block5_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 4, 4,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 4, 4,      │      4,096 │ conv4_block5_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 4, 4,      │          0 │ conv4_block6_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block6_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block6_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 2, 2, 256) │    589,824 │ conv4_block6_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 2, 2,      │          0 │ conv4_block5_out… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 2, 2,      │          0 │ max_pooling2d_2[… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 2, 2,      │      4,096 │ conv4_block6_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 2, 2,      │          0 │ conv5_block1_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 2, 2, 512) │    524,288 │ conv5_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block1_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 2, 2,      │  2,099,200 │ conv5_block1_pre… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 2, 2,      │          0 │ conv5_block1_0_c… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 2, 2,      │      8,192 │ conv5_block1_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 2, 2,      │          0 │ conv5_block2_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 2, 2, 512) │  1,048,576 │ conv5_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 2, 2,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 2, 2,      │      8,192 │ conv5_block2_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 2, 2,      │          0 │ conv5_block3_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 2, 2, 512) │  1,048,576 │ conv5_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 2, 2,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │
20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 192s 737ms/step - loss: 13.5714 - mae: 2.3700 - val_loss: 115.4845 - val_mae: 8.1578

# %%
# Save model and history
mt.save_model_and_history(
    ResNet50V2_model,
    ResNet50V2_history,
    model_name="resnet50v2_model",
    model_dir="models",
    history_dir="models/history",
)
# Out:
# Model saved to models\resnet50v2_model.keras
# Full history saved to models/history\resnet50v2_model_history.pkl

# %%
mt.plot_learning_curve(
    ResNet50V2_history.history["loss"],
    ResNet50V2_history.history["val_loss"],
    ResNet50V2_history.history["mae"],
    ResNet50V2_history.history["val_mae"],
    metric_name="MAE",
)

# %% [markdown]
# **NasNetMobile**
#
# 1. **Neural Architecture Search Optimized**
#    NASNetMobile leverages automated neural architecture search to design efficient, modular building blocks, achieving a good balance between accuracy and computational cost.
#
# 2. **Flexible and Modular Design**
#    Its cell-based architecture allows customization and easy scaling to fit specific agricultural imaging tasks without excessive computational overhead.
#
# 4. **Good Transfer Learning Performance**
#    Pretrained NASNetMobile models provide strong baseline features, accelerating training and improving performance, especially when data availability is limited or imbalanced.

# %%
# Build the NASNetMobile base model
NASNetMobile_base = NASNetMobile(
    input_shape=INPUT_DIM,
    include_top=False,
    weights=None,  
    pooling='avg'  
)

x = NASNetMobile_base.output
output = Dense(1, activation='linear')(x)

NASNetMobile_model = Model(inputs=NASNetMobile_base.input, outputs=output)

NASNetMobile_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv1 (Conv2D) │ (None, 31, 31,    │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn1            │ (None, 31, 31,    │        128 │ stem_conv1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 31, 31,    │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_conv_1_s… │ (None, 31, 31,    │        352 │ activation_18[0]… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_bn_1_ste… │ (None, 31, 31,    │         44 │ reduction_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 31, 31,    │          0 │ reduction_bn_1_s… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 31, 31,    │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 35, 35,    │          0 │ activation_19[0]… │
# │ (ZeroPadding2D)     │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 37, 37,    │          0 │ activation_21[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 16, 16,    │        396 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 16, 16,    │      1,920 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 16, 16,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 16, 16,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 16, 16,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 16, 16,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 16, 16,    │        396 │ activation_20[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 16, 16,    │        660 │ activation_22[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 31, 31,    │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 16, 16,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 16, 16,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 37, 37,    │          0 │ activation_23[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 31, 31,    │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_1_st… │ (None, 16, 16,    │          0 │ separable_conv_2… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 16, 16,    │      1,920 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 35, 35,    │          0 │ activation_25[0]… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 16, 16,    │          0 │ reduction_add_1_… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 16, 16,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 16, 16,    │      1,152 │ separable_conv_1… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 16, 16,    │        220 │ activation_27[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 16, 16,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 16, 16,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 16, 16,    │         44 │ separable_conv_1… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_pad_1_st… │ (None, 33, 33,    │          0 │ reduction_bn_1_s… │
# │ (ZeroPadding2D)     │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 16, 16,    │        660 │ activation_24[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 16, 16,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 16, 16,    │          0 │ separable_conv_1… │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left2_st… │ (None, 16, 16,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 16, 16,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 16, 16,    │        396 │ activation_26[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 16, 16,    │        220 │ activation_28[0]… │
# │ (SeparableConv2D)   │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_relu_1_stem… │ (None, 31, 31,    │          0 │ stem_bn1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_2_st… │ (None, 16, 16,    │          0 │ reduction_left2_… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left3_st… │ (None, 16, 16,    │          0 │ reduction_pad_1_… │
# │ (AveragePooling2D)  │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 16, 16,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left4_st… │ (None, 16, 16,    │          0 │ reduction_add_1_… │
# │ (AveragePooling2D)  │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 16, 16,    │         44 │ separable_conv_2… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_right5_s… │ (None, 16, 16,    │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 32, 32,    │          0 │ adjust_relu_1_st… │
# │ (ZeroPadding2D)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add3_ste… │ (None, 16, 16,    │          0 │ reduction_left3_… │
# │ (Add)               │ 11)               │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 16, 16,    │          0 │ reduction_add_2_… │
# │                     │ 11)               │            │ reduction_left4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add4_ste… │ (None, 16, 16,    │          0 │ separable_conv_2… │
# │ (Add)               │ 11)               │            │ reduction_right5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d          │ (None, 31, 31,    │          0 │ zero_padding2d[0… │
# │ (Cropping2D)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_concat_s… │ (None, 16, 16,    │          0 │ reduction_add_2_… │
# │ (Concatenate)       │ 44)               │            │ reduction_add3_s… │
# │                     │                   │            │ add_9[0][0],      │
# │                     │                   │            │ reduction_add4_s… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_1_… │ (None, 16, 16,    │          0 │ adjust_relu_1_st… │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_avg_pool_2_… │ (None, 16, 16,    │          0 │ cropping2d[0][0]  │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 16, 16,    │          0 │ reduction_concat… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_1_stem… │ (None, 16, 16,    │        352 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_2_stem… │ (None, 16, 16,    │        352 │ adjust_avg_pool_… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_conv_1_s… │ (None, 16, 16,    │        968 │ activation_29[0]… │
# │ (Conv2D)            │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ adjust_conv_1_st… │
# │ (Concatenate)       │ 22)               │            │ adjust_conv_2_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_bn_1_ste… │ (None, 16, 16,    │         88 │ reduction_conv_1… │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_stem_2    │ (None, 16, 16,    │         88 │ concatenate[0][0] │
# │ (BatchNormalizatio… │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 16, 16,    │          0 │ reduction_bn_1_s… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 16, 16,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 19, 19,    │          0 │ activation_30[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 21, 21,    │          0 │ activation_32[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 8, 8, 22)  │      1,034 │ separable_conv_1… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 8, 8, 22)  │      1,562 │ separable_conv_1… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 8, 8, 22)  │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 8, 8, 22)  │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 8, 8, 22)  │      1,034 │ activation_31[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 8, 8, 22)  │      1,562 │ activation_33[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 16, 16,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 21, 21,    │          0 │ activation_34[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 16, 16,    │          0 │ adjust_bn_stem_2… │
# │ (Activation)        │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_1_st… │ (None, 8, 8, 22)  │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 8, 8, 22)  │      1,562 │ separable_conv_1… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_p… │ (None, 19, 19,    │          0 │ activation_36[0]… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 8, 8, 22)  │          0 │ reduction_add_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 8, 8, 22)  │      1,034 │ separable_conv_1… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_r… │ (None, 8, 8, 22)  │        682 │ activation_38[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 8, 8, 22)  │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_pad_1_st… │ (None, 17, 17,    │          0 │ reduction_bn_1_s… │
# │ (ZeroPadding2D)     │ 22)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 8, 8, 22)  │      1,562 │ activation_35[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 8, 8, 22)  │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 8, 8, 22)  │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left2_st… │ (None, 8, 8, 22)  │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 8, 8, 22)  │      1,034 │ activation_37[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_r… │ (None, 8, 8, 22)  │        682 │ activation_39[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_relu_1_0     │ (None, 16, 16,    │          0 │ reduction_concat… │
# │ (Activation)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add_2_st… │ (None, 8, 8, 22)  │          0 │ reduction_left2_… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left3_st… │ (None, 8, 8, 22)  │          0 │ reduction_pad_1_… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_left4_st… │ (None, 8, 8, 22)  │          0 │ reduction_add_1_… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 22)  │         88 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_right5_s… │ (None, 8, 8, 22)  │          0 │ reduction_pad_1_… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 17, 17,    │          0 │ adjust_relu_1_0[… │
# │ (ZeroPadding2D)     │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add3_ste… │ (None, 8, 8, 22)  │          0 │ reduction_left3_… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 8, 8, 22)  │          0 │ reduction_add_2_… │
# │                     │                   │            │ reduction_left4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction_add4_ste… │ (None, 8, 8, 22)  │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ reduction_right5… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cropping2d_1        │ (None, 16, 16,    │          0 │ zero_padding2d_1… │
# │ (Cropping2D)        │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reduction
0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_1      │ (None, 8, 8, 44)  │          0 │ adjust_bn_1[0][0] │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_1     │ (None, 8, 8, 44)  │          0 │ adjust_bn_1[0][0] │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 8, 8, 44)  │        176 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_1      │ (None, 8, 8, 44)  │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_1      │ (None, 8, 8, 44)  │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_1      │ (None, 8, 8, 44)  │          0 │ normal_left3_1[0… │
# │ (Add)               │                   │            │ adjust_bn_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_1      │ (None, 8, 8, 44)  │          0 │ normal_left4_1[0… │
# │ (Add)               │                   │            │ normal_right4_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_1      │ (None, 8, 8, 44)  │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ normal_bn_1_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_1     │ (None, 8, 8, 264) │          0 │ adjust_bn_1[0][0… │
# │ (Concatenate)       │                   │            │ normal_add_1_1[0… │
# │                     │                   │            │ normal_add_2_1[0… │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_186[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     35,376 │ activation_188[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_190[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_192[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left3_11     │ (None, 2, 2, 176) │          0 │ normal_bn_1_11[0… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_11     │ (None, 2, 2, 176) │          0 │ adjust_bn_11[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_11    │ (None, 2, 2, 176) │          0 │ adjust_bn_11[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_11     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_11     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_11     │ (None, 2, 2, 176) │          0 │ normal_left3_11[… │
# │ (Add)               │                   │            │ adjust_bn_11[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_11     │ (None, 2, 2, 176) │          0 │ normal_left4_11[… │
# │ (Add)               │                   │            │ normal_right4_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_11     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ normal_bn_1_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_11    │ (None, 2, 2,      │          0 │ adjust_bn_11[0][… │
# │ (Concatenate)       │ 1056)             │            │ normal_add_1_11[… │
# │                     │                   │            │ normal_add_2_11[… │
# │                     │                   │            │ normal_add_3_11[… │
# │                     │                   │            │ normal_add_4_11[… │
# │                     │                   │            │ normal_add_5_11[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_193      │ (None, 2, 2,      │          0 │ normal_concat_10… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_194      │ (None, 2, 2,      │          0 │ normal_concat_11… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_conv_projec… │ (None, 2, 2, 176) │    185,856 │ activation_193[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_conv_1_12    │ (None, 2, 2, 176) │    185,856 │ activation_194[0… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ adjust_bn_12        │ (None, 2, 2, 176) │        704 │ adjust_conv_proj… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_bn_1_12      │ (None, 2, 2, 176) │        704 │ normal_conv_1_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_195      │ (None, 2, 2, 176) │          0 │ normal_bn_1_12[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_197      │ (None, 2, 2, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_199      │ (None, 2, 2, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_201      │ (None, 2, 2, 176) │          0 │ adjust_bn_12[0][… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_203      │ (None, 2, 2, 176) │          0 │ normal_bn_1_12[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 2, 2, 176) │     35,376 │ activation_195[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 2, 2, 176) │     32,560 │ activation_197[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 2, 2, 176) │     35,376 │ activation_199[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 2, 2, 176) │     32,560 │ activation_201[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_n… │ (None, 2, 2, 176) │     32,560 │ activation_203[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 2, 2, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 2, 2, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 2, 2, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 2, 2, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_1_b… │ (None, 2, 2, 176) │        704 │ separable_conv_1… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_196      │ (None, 2, 2, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_198      │ (None, 2, 2, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_200      │ (None, 2, 2, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_202      │ (None, 2, 2, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_204      │ (None, 2, 2, 176) │          0 │ separable_conv_1… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     35,376 │ activation_196[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_198[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     35,376 │ activation_200[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_202[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_n… │ (None, 2, 2, 176) │     32,560 │ activation_204[0… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left3_12     │ (None, 2, 2, 176) │          0 │ normal_bn_1_12[0… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_left4_12     │ (None, 2, 2, 176) │          0 │ adjust_bn_12[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_right4_12    │ (None, 2, 2, 176) │          0 │ adjust_bn_12[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv_2_b… │ (None, 2, 2, 176) │        704 │ separable_conv_2… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_1_12     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_2_12     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ separable_conv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_3_12     │ (None, 2, 2, 176) │          0 │ normal_left3_12[… │
# │ (Add)               │                   │            │ adjust_bn_12[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_4_12     │ (None, 2, 2, 176) │          0 │ normal_left4_12[… │
# │ (Add)               │                   │            │ normal_right4_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_add_5_12     │ (None, 2, 2, 176) │          0 │ separable_conv_2… │
# │ (Add)               │                   │            │ normal_bn_1_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normal_concat_12    │ (None, 2, 2,      │          0 │ adjust_bn_12[0][… │
# │ (Concatenate)       │ 1056)             │            │ normal_add_1_12[… │
# │                     │                   │            │ normal_add_2_12[… │
# │                     │                   │            │ normal_add_3_12[… │
# │                     │                   │            │ normal_add_4_12[… │
# │                     │                   │            │ normal_add_5_12[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_205      │ (None, 2, 2,      │          0 │ normal_concat_12… │
# │ (Activation)        │ 1056)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1056)      │          0 │ activation_205[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │      1,057 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,270,773 (16.29 MB)
#  Trainable params: 4,234,035 (16.15 MB)
#  Non-trainable params: 36,738 (143.51 KB)

# %%
# Compile the NASNetMobile model
NASNetMobile_model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# Train the NASNetMobile model
NASNetMobile_history = NASNetMobile_model.fit(
    train_generator_age, validation_data=val_generator_age,
    epochs=20, verbose=1,
)
# Out:
# Epoch 1/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 211s 482ms/step - loss: 1040.0914 - mae: 24.9974 - val_loss: 17130.7383 - val_mae: 129.5762
# Epoch 2/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 135s 517ms/step - loss: 69.0422 - mae: 6.7262 - val_loss: 756.9806 - val_mae: 25.8721
# Epoch 3/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 155s 592ms/step - loss: 58.9106 - mae: 6.0854 - val_loss: 1347.6965 - val_mae: 35.5134
# Epoch 4/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 437ms/step - loss: 44.5344 - mae: 5.1918 - val_loss: 2268.6594 - val_mae: 46.7489
# Epoch 5/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 439ms/step - loss: 37.6065 - mae: 4.6350 - val_loss: 2236.8501 - val_mae: 46.4194
# Epoch 6/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 114s 438ms/step - loss: 29.1659 - mae: 4.0640 - val_loss: 2492.1926 - val_mae: 49.0937
# Epoch 7/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 117s 447ms/step - loss: 25.9144 - mae: 3.7783 - val_loss: 2400.1484 - val_mae: 48.1025
# Epoch 8/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 115s 442ms/step - loss: 20.6917 - mae: 3.3548 - val_loss: 2168.6501 - val_mae: 45.6795
# Epoch 9/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 118s 453ms/step - loss: 18.9028 - mae: 3.1981 - val_loss: 2234.0549 - val_mae: 46.2835
# Epoch 10/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 126s 483ms/step - loss: 15.4443 - mae: 2.8527 - val_loss: 2261.8503 - val_mae: 46.6033
# Epoch 11/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 132s 506ms/step - loss: 14.8197 - mae: 2.7857 - val_loss: 2046.7872 - val_mae: 44.2951
# Epoch 12/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 110s 420ms/step - loss: 15.3972 - mae: 2.8044 - val_loss: 2052.8179 - val_mae: 44.3524
# Epoch 13/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 119s 457ms/step - loss: 14.1217 - mae: 2.6685 - val_loss: 1568.2531 - val_mae: 38.5205
# Epoch 14/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 141s 540ms/step - loss: 9.9358 - mae: 2.2423 - val_loss: 1893.4070 - val_mae: 42.5239
# Epoch 15/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 117s 447ms/step - loss: 11.8983 - mae: 2.4102 - val_loss: 1491.7694 - val_mae: 37.3375
# Epoch 16/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 106s 406ms/step - loss: 11.7166 - mae: 2.3952 - val_loss: 1661.5182 - val_mae: 39.6602
# Epoch 17/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 111s 423ms/step - loss: 9.5121 - mae: 2.1366 - val_loss: 1072.6436 - val_mae: 31.3544
# Epoch 18/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 131s 503ms/step - loss: 9.4427 - mae: 2.1730 - val_loss: 1236.9763 - val_mae: 33.9281
# Epoch 19/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 137s 525ms/step - loss: 7.7393 - mae: 1.9173 - val_loss: 1429.1895 - val_mae: 36.6431
# Epoch 20/20
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 109s 417ms/step - loss: 11.3409 - mae: 2.3474 - val_loss: 794.3376 - val_mae: 26.8093

# %%
# Save model and history
mt.save_model_and_history(
    NASNetMobile_model,
    NASNetMobile_history,
    model_name="nasnetmobile_model",
    model_dir="models",
    history_dir="models/history",
)
# Out:
# Model saved to models\nasnetmobile_model.keras
# Full history saved to models/history\nasnetmobile_model_history.pkl

# %%
mt.plot_learning_curve(
    NASNetMobile_history.history["loss"],
    NASNetMobile_history.history["val_loss"],
    NASNetMobile_history.history["mae"],
    NASNetMobile_history.history["val_mae"],
    metric_name="MAE",
)

# %% [markdown]
# ### 2.3) Model Evaluation
# **Justifications for Using MAE and MSE in Task 3 (Age Prediction)**
#
# **Mean Absolute Error (MAE):**
#
# - **Intuitive interpretation:** MAE measures the average absolute difference between predicted and true ages, directly indicating how many days off the predictions are on average.
# - **Robustness to outliers:** MAE treats all errors linearly, so it is less sensitive to large outliers in age prediction compared to MSE.
# - **Meaningful for real-world impact:** Since age prediction errors translate directly to days, MAE provides a straightforward sense of typical prediction error magnitude, which is often more interpretable for stakeholders like farmers.
#
# **Mean Squared Error (MSE):**
#
# - **Penalizes larger errors more:** By squaring the errors, MSE gives more weight to larger mistakes, encouraging the model to focus on minimizing substantial deviations in predicted age.
# - **Mathematically convenient:** MSE is differentiable and smooth, which helps gradient-based optimization converge efficiently during training.
# - **Common regression metric:** MSE is widely used in regression tasks, providing a standard benchmark to compare model performance across studies and implementations.

# %%
best_mobilenetv3small_epoch = np.argmin(MobileNetV3Small_history.history["val_mae"])
mobilenetv3small_val_mae = MobileNetV3Small_history.history["val_mae"][best_mobilenetv3small_epoch]
mobilenetv3small_train_mae = MobileNetV3Small_history.history["mae"][best_mobilenetv3small_epoch]

best_resnet50v2_epoch = np.argmin(ResNet50V2_history.history["val_mae"])
resnet50v2_val_mae = ResNet50V2_history.history["val_mae"][best_resnet50v2_epoch]
resnet50v2_train_mae= ResNet50V2_history.history["mae"][best_resnet50v2_epoch]

best_nasnetmobile_epoch = np.argmin(NASNetMobile_history.history["val_mae"])
nasnetmobile_val_mae= NASNetMobile_history.history["val_mae"][best_nasnetmobile_epoch]
nasnetmobile_train_mae= NASNetMobile_history.history["mae"][best_nasnetmobile_epoch]

model_results = {
    "MobileNetV3Small": ( mobilenetv3small_train_mae, mobilenetv3small_val_mae),
    "ResNet50V2": (resnet50v2_train_mae, resnet50v2_val_mae),
    "NasNetMobile": (nasnetmobile_train_mae, nasnetmobile_val_mae),
}

# %%
mt.plot_regression_model_results(
    model_results,
    metric_name="MAE",
    title="Model Comparison for Age Prediction",
    figsize=(12, 8),
)

# %% [markdown]
# **Obervations:**
# - NasNetMobile perform quite bad with train_mae (6.62) and the val_mae is very high (25.87) which means that the model is extremely overfitting
# - MobileNetV3Small perform quite well with train_mae (2.45) but there is a gap between the train_mae with the val_mae (7.3374) which means that the model is overfitting
# - ResNet50V2 is the best model with train_mae (2.01) and val_mae (3.37) which means that the model is not overfitting too much and we can apply fine-tuning to enhance the ResNet50V2 model's performance

# %% [markdown]
# ### 2.4) Model Selection and Hyperparameter Tuning

# %% [markdown]
# To handle overfitting situation, we used the following techniques:
# 1. **Early Stopping**:
#     - Monitor the validation loss and stop training when it starts to increase.
#     - Set patience to 10 epochs, meaning training will stop if no improvement is seen for 10 consecutive epochs.
# 2. **Dropout**:
#     - Randomly drop a fraction of neurons during training to prevent co-adaptation.
#     - Set dropout rate to 0.5, meaning 50% of neurons will be dropped.
# 3. **Batch Normalization**:
#     - Normalize the output of a layer to stabilize learning and improve convergence.
#     - Apply batch normalization after each convolutional layer.
# 4. **L2 Regularization**:
#     - Add a penalty to the loss function for large weights to prevent overfitting.
#     - Train the model with several values of L2 regularization (0.01, 0.001, 0.005, 0.0001) to find the best one.

# %% [markdown]
# Creat a subset of the dataset with 30% of the original dataset for speeding up the prcess of selecting best lamda for L2 regularization

# %%
# Create quantile-based bins 
train_df['age_bin'] = pd.qcut(train_df['age'], q=10, duplicates='drop')

subset_df, _ = train_test_split(
    train_df, test_size=0.7, stratify=train_df['age_bin'], random_state=42
)

subset_train_df, subset_val_df = train_test_split(
    subset_df, test_size=0.2, stratify=subset_df['age_bin'], random_state=42
)

# Drop helper column after split
for df in [train_df, subset_df, subset_train_df, subset_val_df]:
    if 'age_bin' in df.columns:
        df.drop(columns=['age_bin'], inplace=True)

train_subset_generator = train_datagen.flow_from_dataframe(
    dataframe=subset_train_df,
    x_col="image_path",
    y_col="age",
    target_size=(64, 64),
    class_mode="raw",
    batch_size=32,
    shuffle=True,
)

val_subset_generator = val_datagen.flow_from_dataframe(
    dataframe=subset_val_df,
    x_col="image_path",
    y_col="age",
    target_size=(64, 64),
    class_mode="raw",
    batch_size=32,
    shuffle=False,
)
# Out:
# Found 1997 validated image filenames.
# Found 500 validated image filenames.

# %%
def build_resnet50v2_model(input_shape, l2_reg=None):
    """
    Builds a ResNet50V2 model for regression with optional L2 regularization.

    Parameters:
    - input_shape: Shape of the input images.
    - l2_reg: keras.regularizers.l2 instance or None.

    Returns:
    - model: Uncompiled ResNet50V2 model.
    """
    base_model = ResNet50V2(
        include_top=False,
        weights=None,
        input_shape=input_shape,
        pooling='avg'
    )

    x = base_model.output
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(1, activation='linear', kernel_regularizer=l2_reg)(x)

    model = Model(inputs=base_model.input, outputs=x)

    return model

# %%
LOAD_FROM_HISTORY = False
if LOAD_FROM_HISTORY:
    lambda_histories = mt.load_lambda_histories()
    model_results = {}

    for model_name, history in lambda_histories.items():
        # For regression, monitor val_mae or val_loss
        best_epoch = np.argmin(history.history["val_mae"])  # or "val_loss"
        val_mae = history.history["val_mae"][best_epoch]
        train_mae = history.history["mae"][best_epoch]
        model_results[model_name] = (train_mae, val_mae)

else:
    lambda_parameters = [0.0001, 0.001, 0.005, 0.01]
    model_results = {}

    for para_l2_strength in lambda_parameters:
        print(f"\nTraining model with L2 regularization lambda = {para_l2_strength}")

        resnet50v2_model = build_resnet50v2_model(input_shape=(64,64,3), l2_reg=l2(para_l2_strength))

        resnet50v2_model.compile(
            optimizer=Adam(learning_rate=0.0001),
            loss="mse",
            metrics=["mae"],
        )

        early_stopping = EarlyStopping(
            monitor="val_mae",  # regression metric, not accuracy
            patience=15,
            restore_best_weights=True
        )

        history = resnet50v2_model.fit(
            train_subset_generator,
            validation_data=val_subset_generator,
            epochs=20,
            callbacks=[early_stopping],
            verbose=1,
        )

        # Save model and history
        model_name = f"resnet50v2_{para_l2_strength}_lambda"
        mt.save_model_and_history(resnet50v2_model, history, model_name)

        # Find best epoch based on lowest val_mae
        best_epoch = np.argmin(history.history["val_mae"])
        val_mae = history.history["val_mae"][best_epoch]
        train_mae = history.history["mae"][best_epoch]

        model_results[model_name] = (train_mae, val_mae)

# Sort by lambda
model_results = dict(
    sorted(model_results.items(), key=lambda x: float(x[0].split("_")[1]))
)
# Out:
# Training model with L2 regularization lambda = 0.0001
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 73s 777ms/step - loss: 4186.5557 - mae: 64.0806 - val_loss: 4325.4878 - val_mae: 65.1449
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 732ms/step - loss: 4115.7915 - mae: 63.6947 - val_loss: 4722.2739 - val_mae: 68.1205
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 778ms/step - loss: 4058.3586 - mae: 63.4045 - val_loss: 4938.3501 - val_mae: 69.6771
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 60s 933ms/step - loss: 3952.7224 - mae: 62.6587 - val_loss: 4930.4585 - val_mae: 69.6035
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 62s 987ms/step - loss: 3787.8975 - mae: 61.3652 - val_loss: 4159.0527 - val_mae: 63.7935
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 3652.5625 - mae: 60.2556 - val_loss: 3774.9702 - val_mae: 60.7062
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 891ms/step - loss: 3475.4470 - mae: 58.7720 - val_loss: 3396.9585 - val_mae: 57.4926
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 815ms/step - loss: 3216.5488 - mae: 56.5220 - val_loss: 2800.9058 - val_mae: 52.0946
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 810ms/step - loss: 2994.7444 - mae: 54.4717 - val_loss: 3181.1367 - val_mae: 55.6422
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 822ms/step - loss: 2685.6360 - mae: 51.5161 - val_loss: 2258.0503 - val_mae: 46.6743
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 805ms/step - loss: 2381.8931 - mae: 48.4439 - val_loss: 2345.7231 - val_mae: 47.5642
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 775ms/step - loss: 2086.6560 - mae: 45.2634 - val_loss: 2202.8792 - val_mae: 46.0030
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 773ms/step - loss: 1790.4958 - mae: 41.8691 - val_loss: 1964.1552 - val_mae: 42.7523
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 796ms/step - loss: 1524.3148 - mae: 38.5065 - val_loss: 1388.8942 - val_mae: 36.1622
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 809ms/step - loss: 1250.5021 - mae: 34.7658 - val_loss: 1089.5337 - val_mae: 31.5001
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 782ms/step - loss: 1053.0146 - mae: 31.6875 - val_loss: 1195.3596 - val_mae: 32.0984
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 770ms/step - loss: 839.9941 - mae: 28.1140 - val_loss: 770.0547 - val_mae: 26.2537
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 758ms/step - loss: 2694.6724 - mae: 51.6077 - val_loss: 2571.8459 - val_mae: 49.8803
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 773ms/step - loss: 2409.0588 - mae: 48.7553 - val_loss: 2387.7085 - val_mae: 47.9244
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 787ms/step - loss: 2105.2683 - mae: 45.4842 - val_loss: 1893.8364 - val_mae: 42.6480
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 761ms/step - loss: 1799.2928 - mae: 41.9867 - val_loss: 1378.6819 - val_mae: 36.1174
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 792ms/step - loss: 1503.2889 - mae: 38.2549 - val_loss: 1435.1742 - val_mae: 36.4406
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 775ms/step - loss: 1277.0695 - mae: 35.1633 - val_loss: 1041.0330 - val_mae: 30.8254
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 791ms/step - loss: 1023.9374 - mae: 31.2773 - val_loss: 711.6608 - val_mae: 25.1090
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 786ms/step - loss: 841.9685 - mae: 28.1835 - val_loss: 704.8674 - val_mae: 24.2560
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 49s 781ms/step - loss: 652.3635 - mae: 24.5286 - val_loss: 408.0508 - val_mae: 17.8701
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 761ms/step - loss: 500.9208 - mae: 21.2091 - val_loss: 418.5314 - val_mae: 18.5499
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 757ms/step - loss: 401.0634 - mae: 18.7406 - val_loss: 295.6856 - val_mae: 14.0069
# Model saved to models\resnet50v2_0.01_lambda.keras
# Full history saved to models/history\resnet50v2_0.01_lambda_history.pkl

# %% [markdown]
# In this case, we can observe that the training MAE is higher than the validation MAE, which is counter-intuitive. This can happen for several reasons:
#
# 1. **Early Stages of Training**
#    Early in training, the model may perform inconsistently on training batches due to random initialization or high learning rate.
#    - The validation MAE might appear temporarily lower if the validation set is easier or more consistent.
#
# 2. **Small Validation Set or Data Distribution Differences**
#    The validation set is small or less complex than the training set, validation error can be artificially lower.
#    - Differences in data distribution or sample difficulty can cause this counter-intuitive result.
#
# However, our purpose is to find the best lambda for L2 regularization and use that L2 `lamda` to train on full dataset, so we only focus on the smallest gap between the train and val MAE. For that reason, the best lambda is 0.005 with the smallest gap of 3.42 between the train and val MAE.

# %%
mt.plot_regression_model_results(
    model_results, "Regression Model MAE Comparison", figsize=(16, 6)
)

# %%
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

train_generator_task3 = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="",
    x_col='image_path',
    y_col='age',
    target_size= (128,128),
    batch_size= BATCH_SIZE,
    class_mode='raw',
    seed=42,
    shuffle=True
)

val_generator_task3 = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory="",
    x_col='image_path',
    y_col='age',
    target_size=(128, 128),
    batch_size=BATCH_SIZE,
    class_mode='raw',
    seed=42,
    shuffle=False
)
# Out:
# Found 8325 validated image filenames.
# Found 2082 validated image filenames.

# %%
resnet50v2_best_model = build_resnet50v2_model(
    input_shape=(128, 128, 3), l2_reg=l2(0.005)
)
resnet50v2_best_model.compile(
    optimizer='adam',
    loss="mse",
    metrics=["mae"],
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6
)

early_stopping = EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

model_checkpoint = ModelCheckpoint(
    './models/resnet50v2_best_model.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the best model on the full training set
resnet50v2_best_history = resnet50v2_best_model.fit(
    train_generator_task3,
    validation_data=val_generator_task3,
    epochs=30,
    callbacks=[reduce_lr, early_stopping, model_checkpoint],
    verbose=1,
)
# Out:
# c:\Anaconda\envs\tf219_env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 719s 3s/step - loss: 2799.9644 - mae: 48.4025 - val_loss: 32246022.0000 - val_mae: 4904.4854 - learning_rate: 0.0010
# Epoch 2/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 570s 2s/step - loss: 111.8475 - mae: 8.5492 - val_loss: 14418.8213 - val_mae: 49.0195 - learning_rate: 0.0010
# Epoch 3/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 567s 2s/step - loss: 106.4644 - mae: 8.1882 - val_loss: 4444.3848 - val_mae: 52.1197 - learning_rate: 0.0010
# Epoch 4/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 606s 2s/step - loss: 101.7412 - mae: 8.0951 - val_loss: 82.6623 - val_mae: 7.3626 - learning_rate: 0.0010
# Epoch 5/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 624s 2s/step - loss: 92.4261 - mae: 7.6443 - val_loss: 76.2758 - val_mae: 7.1707 - learning_rate: 0.0010
# Epoch 6/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 626s 2s/step - loss: 86.1936 - mae: 7.3577 - val_loss: 65.5578 - val_mae: 6.2667 - learning_rate: 0.0010
# Epoch 7/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 600s 2s/step - loss: 79.1930 - mae: 6.9839 - val_loss: 94.5645 - val_mae: 7.2196 - learning_rate: 0.0010
# Epoch 8/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 570s 2s/step - loss: 71.3193 - mae: 6.5674 - val_loss: 110.0896 - val_mae: 8.4095 - learning_rate: 0.0010
# Epoch 9/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 600s 2s/step - loss: 62.5123 - mae: 6.1201 - val_loss: 71.5905 - val_mae: 6.4045 - learning_rate: 5.0000e-04
# Epoch 10/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 628s 2s/step - loss: 59.4734 - mae: 5.9018 - val_loss: 54.1153 - val_mae: 5.4469 - learning_rate: 5.0000e-04
# Epoch 11/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 518s 2s/step - loss: 54.5695 - mae: 5.6270 - val_loss: 85.0913 - val_mae: 7.4947 - learning_rate: 5.0000e-04
# Epoch 12/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - loss: 48.7777 - mae: 5.2618 - val_loss: 77.5236 - val_mae: 7.1162 - learning_rate: 5.0000e-04
# Epoch 13/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 514s 2s/step - loss: 42.1652 - mae: 4.9418 - val_loss: 60.3949 - val_mae: 5.6437 - learning_rate: 2.5000e-04
# Epoch 14/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 512s 2s/step - loss: 37.4283 - mae: 4.5688 - val_loss: 35.7135 - val_mae: 4.3816 - learning_rate: 2.5000e-04
# Epoch 15/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 511s 2s/step - loss: 35.1898 - mae: 4.4527 - val_loss: 39.8830 - val_mae: 4.5010 - learning_rate: 2.5000e-04
# Epoch 16/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 495s 2s/step - loss: 32.2603 - mae: 4.2422 - val_loss: 45.4320 - val_mae: 5.2154 - learning_rate: 2.5000e-04
# Epoch 17/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 495s 2s/step - loss: 28.2423 - mae: 3.9625 - val_loss: 29.7219 - val_mae: 3.9498 - learning_rate: 1.2500e-04
# Epoch 18/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - loss: 25.5886 - mae: 3.7631 - val_loss: 30.1736 - val_mae: 3.9791 - learning_rate: 1.2500e-04
# Epoch 19/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - loss: 24.8979 - mae: 3.7206 - val_loss: 32.2937 - val_mae: 4.1523 - learning_rate: 1.2500e-04
# Epoch 20/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 498s 2s/step - loss: 25.1346 - mae: 3.7066 - val_loss: 29.1682 - val_mae: 3.9099 - learning_rate: 6.2500e-05
# Epoch 21/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - loss: 22.6409 - mae: 3.5170 - val_loss: 28.6724 - val_mae: 3.8372 - learning_rate: 6.2500e-05
# Epoch 22/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - loss: 21.9311 - mae: 3.4398 - val_loss: 29.4789 - val_mae: 3.8245 - learning_rate: 6.2500e-05
# Epoch 23/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - loss: 21.8991 - mae: 3.4689 - val_loss: 27.5262 - val_mae: 3.7125 - learning_rate: 6.2500e-05
# Epoch 24/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - loss: 22.8184 - mae: 3.4782 - val_loss: 27.4388 - val_mae: 3.7335 - learning_rate: 6.2500e-05
# Epoch 25/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - loss: 19.9450 - mae: 3.3207 - val_loss: 26.9929 - val_mae: 3.6887 - learning_rate: 6.2500e-05
# Epoch 26/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 493s 2s/step - loss: 20.9879 - mae: 3.3634 - val_loss: 26.7613 - val_mae: 3.6046 - learning_rate: 6.2500e-05
# Epoch 27/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 495s 2s/step - loss: 20.4271 - mae: 3.3230 - val_loss: 26.2404 - val_mae: 3.5863 - learning_rate: 6.2500e-05
# Epoch 28/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - loss: 18.5960 - mae: 3.1742 - val_loss: 26.2507 - val_mae: 3.6095 - learning_rate: 6.2500e-05
# Epoch 29/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 496s 2s/step - loss: 18.8497 - mae: 3.1759 - val_loss: 25.6294 - val_mae: 3.5176 - learning_rate: 6.2500e-05
# Epoch 30/30
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 494s 2s/step - loss: 18.6580 - mae: 3.1866 - val_loss: 27.1500 - val_mae: 3.5911 - learning_rate: 6.2500e-05

# %%
mt.save_model_and_history(
    resnet50v2_best_model,
    resnet50v2_best_history,
    model_name="resnet50v2_best_model",
    model_dir="models",
    history_dir="models/history",
)
# Out:
# Model saved to models\resnet50v2_best_model.keras
# Full history saved to models/history\resnet50v2_best_model_history.pkl

# %%
mt.plot_learning_curve(
    resnet50v2_best_history.history["loss"],
    resnet50v2_best_history.history["val_loss"],
    resnet50v2_best_history.history["mae"],
    resnet50v2_best_history.history["val_mae"],
    metric_name="MAE",
)

# %%
best_resnet50v2_best_model_epoch = np.argmin(resnet50v2_best_history.history["val_mae"])
resnet50v2_best_model_val_mae= resnet50v2_best_history.history["val_mae"][best_resnet50v2_best_model_epoch]
resnet50v2_best_model_train_mae= resnet50v2_best_history.history["mae"][best_resnet50v2_best_model_epoch]

best_model_results = {
    "ResNet50V2_Best_Model": (resnet50v2_best_model_train_mae, resnet50v2_best_model_val_mae),
}

mt.plot_regression_model_results(
    best_model_results,
    metric_name="MAE",
    title="Finetuned ResNet50V2 Model for Age Prediction",
    figsize=(12, 8),
)

# %% [markdown]
# # III. MODEL PERFORMANCE VISUALIZATION

# %%
best_resnet50v2_model = load_model("./models/resnet50v2_best_model.keras")

mt.predict_and_show_samples_regression(
    model=best_resnet50v2_model,
    df=val_df,
    num_samples=5,
    random_select=True,
    target_size=(128, 128),
    label_col="age",
    error_tolerance=5.0  
)
# Out:
# Predictions within ±5.0 days: 5 out of 5 (100.0%)
